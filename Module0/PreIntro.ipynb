# %%
import pandas as pd
mlb = pd.read_csv("C:/Users/ssuehrin/Downloads/mlbteamstats_20182014.csv")

# %%
mlb[:30]
# Out:
#     YearTeam  RA/G  DefEff    E   DP    W    L   W-L%   ERA  tSho  ...   RBI  \
# 0   2018 ARI  3.98   0.698   75  152   82   80  0.506  3.72     9  ...   658
# 1   2018 ATL  4.06   0.709   80  134   90   72  0.556  3.75    11  ...   717
# 2   2018 BAL  5.51   0.674  104  159   47  115  0.290  5.18     7  ...   593
# 3   2018 BOS  3.99   0.693   77  106  108   54  0.667  3.75    14  ...   829
# 4   2018 CHC  3.96   0.700  104  155   95   68  0.583  3.65    18  ...   722
# 5   2018 CHW  5.23   0.690  114  134   62  100  0.383  4.83     8  ...   639
# 6   2018 CIN  5.06   0.685   95  144   67   95  0.414  4.63     6  ...   665
# 7   2018 CLE  4.00   0.688   83  123   91   71  0.562  3.77    17  ...   786
# 8   2018 COL  4.57   0.688   74  162   91   72  0.558  4.33    10  ...   748
# 9   2018 DET  4.91   0.694   95  126   64   98  0.395  4.58     2  ...   597
# 10  2018 HOU  3.30   0.705   63  116  103   59  0.636  3.11    12  ...   763
# ...

# %%
mlb['BA'].corr(mlb['W'])
# Out:
# 0.36648366227511553

# %%
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
plt.scatter(mlb['salary']/1000000,mlb['W'])
plt.xlabel("Salary $/Millions")
plt.ylabel("Wins 2014-2018")
# Out:
# Text(0,0.5,'Wins 2014-2018')
